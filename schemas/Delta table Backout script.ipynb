# %% [markdown]
# ##Backout Tables

# %% [markdown]
# ### stg Tables backout

# %%
spark.sql("DROP TABLE IF EXISTS stg_subscribers")
spark.sql("DROP TABLE IF EXISTS stg_dependents")
spark.sql("DROP TABLE IF EXISTS stg_coverage")
spark.sql("DROP TABLE IF EXISTS stg_acks")

print("All Stg tables dropped successfully")

# %% [markdown]
# ### Main Tables backout

# %%
spark.sql("DROP TABLE IF EXISTS file_txns")
spark.sql("DROP TABLE IF EXISTS subscribers")
spark.sql("DROP TABLE IF EXISTS dependents")
spark.sql("DROP TABLE IF EXISTS coverage")
spark.sql("DROP TABLE IF EXISTS acks")

print("All main tables dropped successfully")
